# %%
start_year = 2018

# %%
import zipfile
import datetime
 
# Generate the list of quarterly zip files archived in EDGAR since
# start_year (earliest: 1993) until the most recent quarter
current_year = datetime.date.today().year
current_quarter = (datetime.date.today().month - 1) // 3 + 1
#start_year = 2018
years = list(range(start_year, current_year))
quarters = ['QTR1', 'QTR2', 'QTR3', 'QTR4']
history = [(y, q) for y in years for q in quarters]
for i in range(1, current_quarter -1):
    history.append((current_year, 'QTR%d' % i))
quarterly_files = ['https://www.sec.gov/Archives/edgar/full-index/%d/%s/master.zip' % (x[0], x[1]) for x
                   in history]
quarterly_files.sort()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import urllib.request
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)
count=0
for contenturl in quarterly_files:
    print (contenturl)
    count= count+1
    filename = contenturl[45:].replace('/', '_')
    print(filename)
    #try:
    f = open( filename,'wb')
    f.write(urllib.request.urlopen(contenturl).read())
    f.close()
    with zipfile.ZipFile(filename).open('master.idx') as z:
        for i in range(11):
            myarray=z.readline()
        print (myarray)
        records = [tuple(line.decode('latin-1').rstrip().split('|')) for
                       line in z]
        print(records)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">https://www.sec.gov/Archives/edgar/full-index/2018/QTR1/master.zip
# _2018_QTR1_master.zip
# b&apos;--------------------------------------------------------------------------------\r\n&apos;
# [(&apos;1000032&apos;, &apos;BINCH JAMES G&apos;, &apos;4&apos;, &apos;2018-02-16&apos;, &apos;edgar/data/1000032/0000913165-18-000034.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;10-Q&apos;, &apos;2018-02-09&apos;, &apos;edgar/data/1000045/0001193125-18-037381.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;4&apos;, &apos;2018-02-15&apos;, &apos;edgar/data/1000045/0001000045-18-000004.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;4&apos;, &apos;2018-03-08&apos;, &apos;edgar/data/1000045/0001000045-18-000005.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;4&apos;, &apos;2018-03-20&apos;, &apos;edgar/data/1000045/0001609591-18-000001.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;8-K&apos;, &apos;2018-01-09&apos;, &apos;edgar/data/1000045/0001193125-18-007253.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;8-K&apos;, &apos;2018-02-05&apos;, &apos;edgar/data/1000045/0001193125-18-032199.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;8-K&apos;, &apos;2018-02-07&apos;, &apos;edgar/data/1000045/0001193125-18-034693.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;8-K&apos;, &apos;2018-02-20&apos;, &apos;edgar/data/1000045/0001193125-18-049706.txt&apos;), (&apos;1000045&apos;, &apos;NICHOLAS FINANCIAL INC&apos;, &apos;SC 13G/A&apos;, &apos;
000228/0001000228-18-000060.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001193125-18-319632.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001193125-18-326481.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001193125-18-337465.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001193125-18-354900.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001193125-18-358194.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-052820.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-060589.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-060847.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-061643.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-062224.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001209191-18-064398.txt&apos;, &apos;https://www.sec.gov/Archives/edgar/data/1000228/0001000228-18-000056.txt&apos;, &apos;https://www.sec. ...

# %%
dbutils.fs.mkdirs("dbfs:/temp")
dbutils.fs.mkdirs("dbfs:/temp/" + str(start_year))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">33</span><span class="ansired">]: </span>True
# </div>

# %%
for filedown in listfilestodownload:
    print (filedown)
    count= count+1
    filename2 = filedown[48:].replace('/', '_')
    print(filename2)
    #try:
    f = open( '/dbfs/temp/' + str(start_year)  +'/' + filename2,'wb')
    f.write(urllib.request.urlopen(filedown).read())
    f.close()

# %%
dbutils.fs.ls("dbfs:/temp/" + str(start_year))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">49</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/temp/2018/0000000000-18-034845.txt&apos;, name=&apos;0000000000-18-034845.txt&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007099.txt&apos;, name=&apos;0000919574-18-007099.txt&apos;, size=262884),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007801.txt&apos;, name=&apos;0000919574-18-007801.txt&apos;, size=3474339),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007802.txt&apos;, name=&apos;0000919574-18-007802.txt&apos;, size=1335384),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007805.txt&apos;, name=&apos;0000919574-18-007805.txt&apos;, size=1259184),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007848.txt&apos;, name=&apos;0000919574-18-007848.txt&apos;, size=29687),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007897.txt&apos;, name=&apos;0000919574-18-007897.txt&apos;, size=22140),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007935.txt&apos;, name=&apos;0000919574-18-007935.txt&apos;, size=56870),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-007951.txt&apos;, name=&apos;0000919574-18-007951.txt&apos;, size=49917),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-008115.txt&apos;, name=&apos;0000919574-18-008115.txt&apos;, size=52742),
#  FileInfo(path=&apos;dbfs:/temp/2018/0000919574-18-008117.txt&apos;, name=&apos;0000919574-18-008117.txt&apos;, size=77569),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001000097-18-000004.txt&apos;, name=&apos;0001000097-18-000004.txt&apos;, size=54572),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001193125-18-314942.txt&apos;, name=&apos;0001193125-18-314942.txt&apos;, size=143029),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001193125-18-319610.txt&apos;, name=&apos;0001193125-18-319610.txt&apos;, size=680241),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001193125-18-326090.txt&apos;, name=&apos;0001193125-18-326090.txt&apos;, size=3132124),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001193125-18-343069.txt&apos;, name=&apos;0001193125-18-343069.txt&apos;, size=234478),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001357521-18-000008.txt&apos;, name=&apos;0001357521-18-000008.txt&apos;, size=6565),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001357521-18-000009.txt&apos;, name=&apos;0001357521-18-000009.txt&apos;, size=6568),
#  FileInfo(path=&apos;dbfs:/temp/2018/0001357521-18-000010.txt&apos;, name=&apos;0001357521-18-000010.txt&apos;, size=6575)]
# </div>

# %%
finaltocp=[]
import ntpath
for file in dbutils.fs.ls("dbfs:/temp/" + str(start_year)):
  finaltocp.append('temp/' + str(start_year) + '/' + file.name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(finaltocp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&apos;temp/2018/0000000000-18-034845.txt&apos;, &apos;temp/2018/0000919574-18-007099.txt&apos;, &apos;temp/2018/0000919574-18-007801.txt&apos;, &apos;temp/2018/0000919574-18-007802.txt&apos;, &apos;temp/2018/0000919574-18-007805.txt&apos;, &apos;temp/2018/0000919574-18-007848.txt&apos;, &apos;temp/2018/0000919574-18-007897.txt&apos;, &apos;temp/2018/0000919574-18-007935.txt&apos;, &apos;temp/2018/0000919574-18-007951.txt&apos;, &apos;temp/2018/0000919574-18-008115.txt&apos;, &apos;temp/2018/0000919574-18-008117.txt&apos;, &apos;temp/2018/0001000097-18-000004.txt&apos;, &apos;temp/2018/0001193125-18-314942.txt&apos;, &apos;temp/2018/0001193125-18-319610.txt&apos;, &apos;temp/2018/0001193125-18-326090.txt&apos;, &apos;temp/2018/0001193125-18-343069.txt&apos;, &apos;temp/2018/0001357521-18-000008.txt&apos;, &apos;temp/2018/0001357521-18-000009.txt&apos;, &apos;temp/2018/0001357521-18-000010.txt&apos;]
# </div>

# %%
for filecp in finaltocp:
  print('dbfs:/' + filecp)
  #dbutils.fs.cp('dbfs:' + file,'adl:///' + file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/temp/2018/0000000000-18-034845.txt
# dbfs:/temp/2018/0000919574-18-007099.txt
# dbfs:/temp/2018/0000919574-18-007801.txt
# dbfs:/temp/2018/0000919574-18-007802.txt
# dbfs:/temp/2018/0000919574-18-007805.txt
# dbfs:/temp/2018/0000919574-18-007848.txt
# dbfs:/temp/2018/0000919574-18-007897.txt
# dbfs:/temp/2018/0000919574-18-007935.txt
# dbfs:/temp/2018/0000919574-18-007951.txt
# dbfs:/temp/2018/0000919574-18-008115.txt
# dbfs:/temp/2018/0000919574-18-008117.txt
# dbfs:/temp/2018/0001000097-18-000004.txt
# dbfs:/temp/2018/0001193125-18-314942.txt
# dbfs:/temp/2018/0001193125-18-319610.txt
# dbfs:/temp/2018/0001193125-18-326090.txt
# dbfs:/temp/2018/0001193125-18-343069.txt
# dbfs:/temp/2018/0001357521-18-000008.txt
# dbfs:/temp/2018/0001357521-18-000009.txt
# dbfs:/temp/2018/0001357521-18-000010.txt
# </div>

# %%
dbutils.fs.head("dbfs:/temp/2018/0000919574-18-007099.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# <span class="ansired">Out[</span><span class="ansired">53</span><span class="ansired">]: </span>&apos;&lt;SEC-DOCUMENT&gt;0000919574-18-007099.txt : 20181113\n&lt;SEC-HEADER&gt;0000919574-18-007099.hdr.sgml : 20181113\n&lt;ACCEPTANCE-DATETIME&gt;20181113121631\nACCESSION NUMBER:\t\t0000919574-18-007099\nCONFORMED SUBMISSION TYPE:\t6-K\nPUBLIC DOCUMENT COUNT:\t\t4\nCONFORMED PERIOD OF REPORT:\t20181130\nFILED AS OF DATE:\t\t20181113\nDATE AS OF CHANGE:\t\t20181113\n\nFILER:\n\n\tCOMPANY DATA:\t\n\t\tCOMPANY CONFORMED NAME:\t\t\tNORDIC AMERICAN TANKERS Ltd\n\t\tCENTRAL INDEX KEY:\t\t\t0001000177\n\t\tSTANDARD INDUSTRIAL CLASSIFICATION:\tWATER TRANSPORTATION [4400]\n\t\tIRS NUMBER:\t\t\t\t000000000\n\t\tFISCAL YEAR END:\t\t\t1231\n\n\tFILING VALUES:\n\t\tFORM TYPE:\t\t6-K\n\t\tSEC ACT:\t\t1934 Act\n\t\tSEC FILE NUMBER:\t001-13944\n\t\tFILM NUMBER:\t\t181176592\n\n\tBUSINESS ADDRESS:\t\n\t\tSTREET 1:\t\tLOM BUILDING\n\t\tSTREET 2:\t\t27 REID STREET\n\t\tCITY:\t\t\tHAMILTON HM 11\n\t\tSTATE:\t\t\tD0\n\t\tZIP:\t\t\t00000\n\t\tBUSINESS PHONE:\t\t(441) 292-7202\n\n\tMAIL ADDRESS:\t\n\t\tSTREET 1:\t\tLOM BUILDING\n\t\tSTREET 2:\t\t27 REID STREET\n\t\tCITY:\t\t\tHAMILTON HM 11\n\t\tSTATE:\t\t\tD0\n\t\tZIP:\t\t\t00000\n\n\tFORMER COMPANY:\t\n\t\tFORMER CONFORMED NAME:\tNORDIC AMERICAN TANKER SHIPPING LTD\n\t\tDATE OF NAME CHANGE:\t19950906\n&lt;/SEC-HEADER&gt;\n&lt;DOCUMENT&gt;\n&lt;TYPE&gt;6-K\n&lt;SEQUENCE&gt;1\n&lt;FILENAME&gt;d8103348_6-k.htm\n&lt;TEXT&gt;\n&lt;html&gt;\n&lt;head&gt;\n&lt;title&gt;&lt;/title&gt;\n&lt;!--Licensed to: Sewatd &amp; Kissel LLP\n    Document created using EDGARfilings PROfile 4.5.0.0\n    Copyright 1995 - 2018 Broadridge--&gt;\n&lt;/head&gt;\n&lt;body style=&quot;FONT-SIZE: 10pt; FONT-FAMILY: \&apos